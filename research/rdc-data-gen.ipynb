# %% [markdown]
# # RDC Data Generation
#
# This notebook generates and analyzes synthetic data for the Radial Deformation Correction (RDC) model.
#
# **Key Functions:**
# 1. **Data Loading**: Reads bubble properties from CSV files.
# 2. **Statistical Analysis**: Computes pixel counts and dimensions (width/height).
# 3. **Visualization**: Plots histograms of bubble characteristics.
# 4. **Synthetic Data Creation**: Generates training datasets for the RDC model.
#
# **Input**: `data/RDC/Synth_Testdata`
# **Output**: `data/RDC/Synthetic_RDC`

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import hashlib
import shutil
import random
import multiprocessing
import tensorflow as tf
from utils_StarBub import HiddenReco, RDObj, Bubble
from stardist import fill_label_holes
from skimage.draw import polygon

# %%
# Configuration
SOURCE_DIR = os.path.abspath('../data/RDC/Synth_Testdata')
DEST_DIR = os.path.abspath('../data/RDC/Synth_Reconstructed')
UNIQUE_DIR = os.path.abspath('../data/RDC/Synth_Unique')
RDC_DIR = os.path.abspath('../data/RDC/Synthetic_RDC')
MODEL_PATH = os.path.abspath('../Models/RDC/RDC_PAPER')
IMG_SIZE = (256, 256)
METRIC = 5.3E-5 # Optimized Metric

# %% [markdown]
# ## 1. Original Data Analysis & Statistics

# %% [markdown]
# ### 1.1 Bubble Statistics

# %%
def load_data(source_dir):
    print("Loading data...")
    alpha_folders = glob.glob(os.path.join(source_dir, 'alpha_*'))
    stats = []
    
    for alpha_folder in alpha_folders:
        folder_name = os.path.basename(alpha_folder)
        alpha_val = folder_name.replace('alpha_', '')
        print(f"Processing {folder_name}...")
        
        csv_files = glob.glob(os.path.join(alpha_folder, '_PointsImage*', '_Count_*.csv'))
        
        for csv_path in tqdm(csv_files):
            try:
                df = pd.read_csv(csv_path, skipinitialspace=True)
                if 'x' not in df.columns or 'y' not in df.columns:
                     df = pd.read_csv(csv_path)
                     df.columns = [c.strip() for c in df.columns]
                
                if len(df) == 0:
                    continue
                    
                # 1. Pixel Count
                pixel_count = len(df)
                
                # 2. Dimensions
                # Cast to int as requested
                x_values = df['x'].astype(int)
                y_values = df['y'].astype(int)
                
                width = x_values.max() - x_values.min() + 1
                height = y_values.max() - y_values.min() + 1
                
                stats.append({
                    'alpha': alpha_val,
                    'pixel_count': pixel_count,
                    'width': width,
                    'height': height
                })
            except Exception as e:
                print(f"Error reading {csv_path}: {e}")
                
    return pd.DataFrame(stats)

# %% [markdown]
# ### 1.2 Statistical Visualization

# %%
def plot_pixel_counts(df):
    # 1. Plot All
    plt.figure(figsize=(10, 6))
    plt.hist(df['pixel_count'], bins=50, color='skyblue', edgecolor='black')
    plt.title('Distribution of Pixel Counts (All Bubbles)')
    plt.xlabel('Number of Pixels')
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.show()
    
    # 2. Plot per Alpha
    alphas = sorted(df['alpha'].unique())
    for alpha in alphas:
        subset = df[df['alpha'] == alpha]
        plt.figure(figsize=(10, 6))
        plt.hist(subset['pixel_count'], bins=30, color='lightgreen', edgecolor='black')
        plt.title(f'Distribution of Pixel Counts (Alpha = {alpha})')
        plt.xlabel('Number of Pixels')
        plt.ylabel('Frequency')
        plt.grid(True, alpha=0.3)
        plt.show()

# %%
def plot_dimensions(df):
    # 1. Plot All
    plt.figure(figsize=(10, 6))
    plt.hist(df['width'], bins=50, alpha=0.5, label='Width', color='blue', edgecolor='black')
    plt.hist(df['height'], bins=50, alpha=0.5, label='Height', color='orange', edgecolor='black')
    plt.title('Distribution of Dimensions (All Bubbles)')
    plt.xlabel('Size (pixels)')
    plt.ylabel('Frequency')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()
    
    # 2. Plot per Alpha
    alphas = sorted(df['alpha'].unique())
    for alpha in alphas:
        subset = df[df['alpha'] == alpha]
        plt.figure(figsize=(10, 6))
        plt.hist(subset['width'], bins=30, alpha=0.5, label='Width', color='blue', edgecolor='black')
        plt.hist(subset['height'], bins=30, alpha=0.5, label='Height', color='orange', edgecolor='black')
        plt.title(f'Distribution of Dimensions (Alpha = {alpha})')
        plt.xlabel('Size (pixels)')
        plt.ylabel('Frequency')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()

# %%
def print_summary(df):
    print("\n--- Statistics Summary ---")
    print(df.describe())
    
    print("\n--- Summary by Alpha (Mean) ---")
    print(df.groupby('alpha').mean())
    
    print("\n--- Width Statistics by Alpha ---")
    print(df.groupby('alpha')['width'].agg(['min', 'max', 'mean']))
    
    print("\n--- Height Statistics by Alpha ---")
    print(df.groupby('alpha')['height'].agg(['min', 'max', 'mean']))

# %% [markdown]
# # 2. Bubble Reconstruction (png) & Data Filtering

# %% [markdown]
# 2.1 Draw Bubbles
#   - Each CSV file stores all pixel coordinates of a bubble on the original image background
#   - Create images, each bubble placed on a 256x256 background

# %%
from stardist import fill_label_holes

def generate_images(source_dir, dest_dir):
    print("Starting image generation...")
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
        
    alpha_folders = glob.glob(os.path.join(source_dir, 'alpha_*'))
    
    count = 0
    for alpha_folder in alpha_folders:
        folder_name = os.path.basename(alpha_folder)
        dest_alpha_folder = os.path.join(dest_dir, folder_name)
        if not os.path.exists(dest_alpha_folder):
            os.makedirs(dest_alpha_folder)
            
        print(f"Generating images for {folder_name}...")
        
        # Find _PointsImage folders
        points_folders = glob.glob(os.path.join(alpha_folder, '_PointsImage*'))
        
        for points_folder in tqdm(points_folders):
            image_id = os.path.basename(points_folder).replace('_PointsImage', '')
            csv_files = glob.glob(os.path.join(points_folder, '_Count_*.csv'))
            
            for csv_path in csv_files:
                try:
                    bubble_id = os.path.basename(csv_path).replace('_Count_', '').replace('.csv', '')
                    output_filename = f"{image_id}_{bubble_id}.png"
                    output_path = os.path.join(dest_alpha_folder, output_filename)
                    
                    # Read CSV
                    df = pd.read_csv(csv_path, skipinitialspace=True)
                    if 'x' not in df.columns or 'y' not in df.columns:
                         df = pd.read_csv(csv_path)
                         df.columns = [c.strip() for c in df.columns]
                    
                    if len(df) == 0:
                        continue
                        
                    # Cast to int
                    x = df['x'].astype(int).values
                    y = df['y'].astype(int).values
                    
                    # Shift to (0, 0)
                    min_x = np.min(x)
                    min_y = np.min(y)
                    
                    x_shifted = x - min_x
                    y_shifted = y - min_y
                    
                    # Create image
                    img = Image.new('L', IMG_SIZE, 0)
                    pixels = img.load()
                    
                    # Set pixels
                    for i in range(len(x_shifted)):
                        px, py = x_shifted[i], y_shifted[i]
                        if 0 <= px < IMG_SIZE[0] and 0 <= py < IMG_SIZE[1]:
                            pixels[int(px), int(py)] = 255
                    
                    # --- FILL HOLES (StarDist) ---
                    img_arr = np.array(img)
                    # StarDist fill_label_holes yêu cầu ảnh nhãn (integer label image)
                    # Ảnh của bạn đang là binary (0 và 255), nên hàm vẫn hoạt động tốt, 
                    # nó sẽ coi 255 là label của vật thể.
                    img_filled_arr = fill_label_holes(img_arr)
                    img = Image.fromarray(img_filled_arr, mode='L')
                    # -----------------------------
                            
                    img.save(output_path)
                    count += 1
                    
                except Exception as e:
                    print(f"Error processing {csv_path}: {e}")
                    
    print(f"\nGeneration Complete! Generated {count} images.")

# %% [markdown]
# 2.2 Validate generated bubbles against original CSV files based on:
#  - Bubble Pixel count
#  - Bubble height
#  - Bubble width

# %%
def verify_generation(source_dir, dest_dir):
    print("Starting verification...")
    alpha_folders = glob.glob(os.path.join(dest_dir, 'alpha_*'))
    
    total_checked = 0
    errors = 0
    
    for alpha_folder in alpha_folders:
        folder_name = os.path.basename(alpha_folder)
        print(f"Verifying {folder_name}...")
        
        images = glob.glob(os.path.join(alpha_folder, '*.png'))
        
        for img_path in tqdm(images):
            try:
                filename = os.path.basename(img_path)
                image_id, bubble_id = filename.replace('.png', '').split('_')
                
                # 1. Analyze Image
                img = Image.open(img_path)
                img_arr = np.array(img)
                
                # Pixel Count
                pixel_count_img = np.count_nonzero(img_arr)
                
                # Dimensions from Image
                rows, cols = np.nonzero(img_arr)
                if len(rows) == 0:
                    width_img = 0
                    height_img = 0
                else:
                    # Note: rows are y, cols are x
                    min_y, max_y = np.min(rows), np.max(rows)
                    min_x, max_x = np.min(cols), np.max(cols)
                    width_img = max_x - min_x + 1
                    height_img = max_y - min_y + 1
                
                # 2. Analyze CSV
                csv_path = os.path.join(source_dir, folder_name, f'_PointsImage{image_id}', f'_Count_{bubble_id}.csv')
                if not os.path.exists(csv_path):
                    print(f"CSV missing for {filename}")
                    continue
                    
                df = pd.read_csv(csv_path, skipinitialspace=True)
                if 'x' not in df.columns or 'y' not in df.columns:
                     df = pd.read_csv(csv_path)
                     df.columns = [c.strip() for c in df.columns]
                
                # Pixel Count (Rows)
                pixel_count_csv = len(df)
                
                # Dimensions from CSV (int cast)
                x = df['x'].astype(int)
                y = df['y'].astype(int)
                width_csv = x.max() - x.min() + 1
                height_csv = y.max() - y.min() + 1
                
                # 3. Compare
                if pixel_count_img != pixel_count_csv:
                    print(f"Mismatch Pixel Count {filename}: Img={pixel_count_img}, CSV={pixel_count_csv}")
                    errors += 1
                elif width_img != width_csv:
                    print(f"Mismatch Width {filename}: Img={width_img}, CSV={width_csv}")
                    errors += 1
                elif height_img != height_csv:
                    print(f"Mismatch Height {filename}: Img={height_img}, CSV={height_csv}")
                    errors += 1
                    
                total_checked += 1
                
            except Exception as e:
                print(f"Error verifying {filename}: {e}")
                
    print(f"\nVerification Complete!")
    print(f"Total Checked: {total_checked}")
    print(f"Errors Found: {errors}")

# %% [markdown]
# 2.3 Identify duplicate bubbles

# %%
def check_duplicates(dest_dir):
    print("Checking for duplicates...")
    alpha_folders = glob.glob(os.path.join(dest_dir, 'alpha_*'))
    
    # Dictionary to store hash -> list of filenames
    hashes = {}
    
    for alpha_folder in alpha_folders:
        folder_name = os.path.basename(alpha_folder)
        print(f"Scanning {folder_name}...")
        
        images = glob.glob(os.path.join(alpha_folder, '*.png'))
        
        for img_path in tqdm(images):
            try:
                with open(img_path, 'rb') as f:
                    file_hash = hashlib.md5(f.read()).hexdigest()
                    
                if file_hash in hashes:
                    hashes[file_hash].append(img_path)
                else:
                    hashes[file_hash] = [img_path]
            except Exception as e:
                print(f"Error hashing {img_path}: {e}")
                
    # Find duplicates
    duplicates = {k: v for k, v in hashes.items() if len(v) > 1}
    
    print(f"\nFound {len(duplicates)} groups of duplicates.")
    
    if len(duplicates) > 0:
        print("\nDuplicate Groups:")
        for h, paths in duplicates.items():
            print(f"Hash: {h}")
            for p in paths:
                print(f"  - {p}")
            print("-" * 20)

# %% [markdown]
# 2.4 Remove duplicate bubbles

# %%
def filter_unique_bubbles(dest_dir, unique_dir):
    print("Filtering unique bubbles...")
    if not os.path.exists(unique_dir):
        os.makedirs(unique_dir)
    else:
        # Clean up existing
        shutil.rmtree(unique_dir)
        os.makedirs(unique_dir)
        
    alpha_folders = glob.glob(os.path.join(dest_dir, 'alpha_*'))
    
    seen_hashes = set()
    count = 0
    
    for alpha_folder in alpha_folders:
        folder_name = os.path.basename(alpha_folder)
        print(f"Scanning {folder_name}...")
        
        images = glob.glob(os.path.join(alpha_folder, '*.png'))
        
        for img_path in tqdm(images):
            try:
                with open(img_path, 'rb') as f:
                    file_hash = hashlib.md5(f.read()).hexdigest()
                    
                if file_hash not in seen_hashes:
                    seen_hashes.add(file_hash)
                    
                    # Copy to unique folder
                    new_filename = f"bubble_{count}.png"
                    new_path = os.path.join(unique_dir, new_filename)
                    shutil.copy(img_path, new_path)
                    count += 1
                    
            except Exception as e:
                print(f"Error processing {img_path}: {e}")
                
    print(f"\nFiltering Complete!")
    print(f"Total Unique Bubbles: {count}")

# %% [markdown]
# # 3. Generate Synthetic RDC Data (Synthetic RDC Data)

# %% [markdown]
# ### 3.1 Generate Overlapping Images
#   - Randomly select 2-3 images (representing 2-3 bubbles)
#   - Place bubbles overlapping each other at random positions
#   - Create overlapping mask

# %%
def generate_rdc_data(unique_dir, rdc_dir, num_samples=60000):
    print("Generating RDC data (Corrected User Algo - With Rotation)...")
    mask_dir = os.path.join(rdc_dir, 'Masks')
    if not os.path.exists(mask_dir):
        os.makedirs(mask_dir)
        
    # Phần đầu giữ nguyên: Load bubbles
    bubble_paths = glob.glob(os.path.join(unique_dir, '*.png'))
    bubbles = []
    bubble_names = []
    for p in tqdm(bubble_paths, desc="Loading bubbles"):
        try:
            img = Image.open(p)
            arr = np.array(img) > 128
            bubbles.append(arr)
            bubble_names.append(os.path.basename(p))
        except Exception as e:
            print(f"Error loading {p}: {e}")
            
    print(f"Loaded {len(bubbles)} unique bubbles.")
    
    # Helper
    def get_crop_size(bubble_arr):
        rows, cols = np.nonzero(bubble_arr)
        if len(rows) == 0: return 0, 0
        return rows.max() - rows.min() + 1, cols.max() - cols.min() + 1
        
    def place_bubble(bubble_arr, r, c):
        rows, cols = np.nonzero(bubble_arr)
        if len(rows) == 0: return None
        min_r, max_r = rows.min(), rows.max()
        min_c, max_c = cols.min(), cols.max()
        crop = bubble_arr[min_r:max_r+1, min_c:max_c+1]
        
        canvas = np.zeros(IMG_SIZE, dtype=bool)
        start_r = max(0, r); end_r = min(IMG_SIZE[0], r + crop.shape[0])
        start_c = max(0, c); end_c = min(IMG_SIZE[1], c + crop.shape[1])
        
        crop_start_r = start_r - r
        crop_end_r = crop_start_r + (end_r - start_r)
        crop_start_c = start_c - c
        crop_end_c = crop_start_c + (end_c - start_c)
        
        if end_r > start_r and end_c > start_c:
            canvas[start_r:end_r, start_c:end_c] = crop[crop_start_r:crop_end_r, crop_start_c:crop_end_c]
            return canvas
        return None

    success_count = 0
    pbar = tqdm(total=num_samples)
    
    while success_count < num_samples:
        # B1: Chọn 2-3 bọt random
        num_bubbles = random.choice([2, 3])
        if len(bubbles) < num_bubbles: break
        
        selected_indices = random.sample(range(len(bubbles)), num_bubbles)
        
        # Tạo danh sách tạm để sort
        current_selection = []
        for idx in selected_indices:
            arr = bubbles[idx]
            
            area = np.count_nonzero(arr)
            name = bubble_names[idx]
            current_selection.append({'arr': arr, 'area': area, 'name': name})
            
        # Sort giảm dần theo diện tích (như yêu cầu)
        current_selection.sort(key=lambda x: x['area'], reverse=True)
        
        current_matrix = np.zeros(IMG_SIZE, dtype=np.uint8)
        placed_positions = []
        placement_failed = False
        
        # B2: Đặt bọt
        for i, b_data in enumerate(current_selection):
            b_arr = b_data['arr']
            b_h, b_w = get_crop_size(b_arr)
            b_val = i + 1
            
            placed_step = False
            retries = 0
            
            while not placed_step and retries < 50:
                # Chọn vị trí
                if i == 0:
                    margin_h = int(b_h * 0.2); margin_w = int(b_w * 0.2)
                    r = random.randint(-margin_h, max(0, IMG_SIZE[0] - b_h + margin_h))
                    c = random.randint(-margin_w, max(0, IMG_SIZE[1] - b_w + margin_w))
                else:
                    # Target vào bọt cũ
                    y_idxs, x_idxs = np.nonzero(current_matrix)
                    if len(y_idxs) > 0:
                        p_idx = random.randint(0, len(y_idxs) - 1)
                        target_r, target_c = y_idxs[p_idx], x_idxs[p_idx]
                        margin_h = int(b_h * 0.9); margin_w = int(b_w * 0.9)
                        
                        min_r = max(-margin_h, target_r - b_h + 1)
                        max_r = min(IMG_SIZE[0] - int(b_h * 0.1), target_r)
                        r = random.randint(min_r, max_r) if min_r < max_r else min_r
                        
                        min_c = max(-margin_w, target_c - b_w + 1)
                        max_c = min(IMG_SIZE[1] - int(b_w * 0.1), target_c)
                        c = random.randint(min_c, max_c) if min_c < max_c else min_c
                    else:
                        r = random.randint(0, IMG_SIZE[0]-b_h); c = random.randint(0, IMG_SIZE[1]-b_w)

                temp_mask = place_bubble(b_arr, r, c)
                if temp_mask is None or np.count_nonzero(temp_mask) == 0:
                    retries += 1; continue
                
                # Check logic: < 0.1 visible -> retry
                backup_matrix = current_matrix.copy()
                current_matrix[temp_mask] = b_val
                
                valid_step = True
                for k in range(i + 1):
                    val_k = k + 1
                    area_visible = np.count_nonzero(current_matrix == val_k)
                    area_orig = current_selection[k]['area']
                    if area_visible < area_orig * 0.1:
                        valid_step = False; break
                
                if valid_step:
                    placed_positions.append((r, c))
                    placed_step = True
                else:
                    current_matrix = backup_matrix
                    retries += 1
            
            if not placed_step:
                placement_failed = True; break
        
        if placement_failed: continue
            
        # Global check: Nếu bất kỳ bọt nào (trừ bọt cuối) > 0.9 visible -> Fail
        final_valid = True
        for k in range(num_bubbles - 1):
            val_k = k + 1
            vis = np.count_nonzero(current_matrix == val_k)
            orig = current_selection[k]['area']
            if vis / orig > 0.9:
                final_valid = False; break
                
        if not final_valid: continue
            
        # Save...
        img_name = f"fixed_rdc_{success_count}.png"
        Image.fromarray(current_matrix).save(os.path.join(mask_dir, img_name))
        
        # Save CSV...
        csv_name = f"fixed_rdc_{success_count}.csv"
        with open(os.path.join(mask_dir, csv_name), 'w') as f:
            f.write("pixel_value,source_bubble,r,c\n")
            f.write("0,background,0,0\n")
            for i, d in enumerate(current_selection):
                f.write(f"{i+1},{d['name']},{placed_positions[i][0]},{placed_positions[i][1]}\n")

        success_count += 1
        pbar.update(1)
    pbar.close()

# %%
def visualize_single_sample_rays(rdc_dir, unique_dir):
    mask_dir = os.path.join(rdc_dir, 'Masks')
    csv_files = glob.glob(os.path.join(mask_dir, '*.csv'))
    
    if not csv_files:
        print("No CSV files found.")
        return

    while True:
        csv_path = random.choice(csv_files)
        mask_filename = os.path.basename(csv_path).replace('.csv', '.png')
        mask_path = os.path.join(mask_dir, mask_filename)
        if os.path.exists(mask_path): break
            
    print(f"Selected Sample: {mask_filename}")
    df = pd.read_csv(csv_path)
    mask_img = Image.open(mask_path)
    labels = np.array(mask_img)
    bubble_ids = [i for i in np.unique(labels) if i != 0]

    def get_bubble_bbox(bubble_arr, pad=20):
        rows, cols = np.nonzero(bubble_arr)
        if len(rows) == 0: return None
        min_r, max_r = rows.min(), rows.max()
        min_c, max_c = cols.min(), cols.max()
        r_start = max(0, min_r - pad)
        r_end = min(bubble_arr.shape[0], max_r + pad)
        c_start = max(0, min_c - pad)
        c_end = min(bubble_arr.shape[1], max_c + pad)
        return r_start, r_end, c_start, c_end

    plt.figure(figsize=(6, 6))
    color_mask = np.zeros((*labels.shape, 3), dtype=np.uint8)
    for bid in bubble_ids:
        color = np.random.randint(50, 255, size=3)
        color_mask[labels == bid] = color
    plt.imshow(color_mask)
    plt.title(f"Recolored Scene\n{mask_filename}")
    plt.axis('off')
    plt.show()

    for idx, bid in enumerate(bubble_ids):
        matches = df[df['pixel_value'] == bid]
        if len(matches) == 0: continue
        csv_row = matches.iloc[0]
        source_name = csv_row['source_bubble']
        r_pos, c_pos = int(csv_row['r']), int(csv_row['c'])
        
        # --- OCCLUDED VIEW (Zoom) ---
        rdc_input = RDObj(bid, 64)
        rdc_input.generateRD_manual(labels)
        
        if rdc_input.center is not None:
            bbox = get_bubble_bbox(labels == bid, pad=30)
            if bbox:
                r1, r2, c1, c2 = bbox
                plt.figure(figsize=(6, 6))
                display_img = np.zeros_like(labels)
                display_img[labels == bid] = 1
                
                # # --- MASKING ---
                # if rdc_input.points is not None and len(rdc_input.points) > 0:
                #     rr, cc = polygon(rdc_input.points[:, 0], rdc_input.points[:, 1], display_img.shape)
                #     poly_mask = np.zeros_like(display_img)
                #     poly_mask[rr, cc] = 1
                #     display_img = display_img * poly_mask
                # ---------------
                
                plt.imshow(display_img, cmap='gray')
                rdc_input.drawRD(plt.gca(), color='cyan', linewidths=1.5)
                
                # --- CONNECT RAYS (Modified) ---
                if rdc_input.points is not None and len(rdc_input.points) > 0:
                     pts = rdc_input.points
                     pts_closed = np.vstack([pts, pts[0]])
                     # Plot x vs y (points[:,1] vs points[:,0])
                     plt.plot(pts_closed[:,1], pts_closed[:,0], color='cyan', linewidth=1.5)
                # -------------------------------
                
                plt.plot(rdc_input.center[1], rdc_input.center[0], 'ro', markersize=5)
                plt.xlim(c1, c2); plt.ylim(r2, r1)
                plt.title(f"Bubble {bid} - Occluded View")
                plt.axis('off'); plt.show()
                input_center_global = rdc_input.center
            else:
                input_center_global = None
        else:
            input_center_global = None

        # --- FULL SOURCE VIEW (No Rotation) ---
        source_path = os.path.join(unique_dir, source_name)
        if os.path.exists(source_path) and input_center_global is not None:
            src_img = Image.open(source_path)
            src_arr = np.array(src_img) > 128 
            
            rows, cols = np.nonzero(src_arr)
            if len(rows) > 0:
                min_r, max_r = rows.min(), rows.max()
                min_c, max_c = cols.min(), cols.max()
                pad = 20
                full_crop = src_arr[min_r:max_r+1, min_c:max_c+1]
                padded_crop = np.pad(full_crop.astype(int), pad, mode='constant', constant_values=0)
                
                local_y = input_center_global[0] - r_pos + pad
                local_x = input_center_global[1] - c_pos + pad
                local_center = (local_y, local_x)
                
                rdc_target = RDObj(1, 64, center=local_center)
                rdc_target.generateRD_manual(padded_crop)
                
                plt.figure(figsize=(6, 6))
                
                # --- MASKING ---
                if rdc_target.points is not None and len(rdc_target.points) > 0:
                    rr, cc = polygon(rdc_target.points[:, 0], rdc_target.points[:, 1], padded_crop.shape)
                    poly_mask = np.zeros_like(padded_crop)
                    poly_mask[rr, cc] = 1
                    padded_crop = padded_crop * poly_mask
                # ---------------
                
                plt.imshow(padded_crop, cmap='gray')
                rdc_target.drawRD(plt.gca(), color='lime', linewidths=1.5)
                
                # --- CONNECT RAYS (Modified) ---
                if rdc_target.points is not None and len(rdc_target.points) > 0:
                     pts = rdc_target.points
                     pts_closed = np.vstack([pts, pts[0]])
                     plt.plot(pts_closed[:,1], pts_closed[:,0], color='lime', linewidth=1.5)
                # -------------------------------

                plt.plot(local_center[1], local_center[0], 'ro', markersize=5)
                plt.title(f"Bubble {bid} - Full Source")
                plt.axis('off'); plt.show()

# %% [markdown]
# 3.2 Validate generated images based on conditions: (must see over 10% of bubble area)

# %%
def verify_geometry(rdc_dir, unique_dir, num_samples_to_check=1000):
    print(f"Verifying geometric constraints on {num_samples_to_check} random samples...")
    
    mask_dir = os.path.join(rdc_dir, 'Masks')
    csv_files = glob.glob(os.path.join(mask_dir, '*.csv'))
    
    if len(csv_files) == 0:
        print("No data found.")
        return

    selected_files = random.sample(csv_files, min(len(csv_files), num_samples_to_check))
    
    violations = 0
    total_bubbles = 0
    violation_list = []
    
    # Cache for unique bubble areas to speed up
    bubble_area_cache = {}
    
    for csv_path in tqdm(selected_files):
        try:
            # Load CSV
            df = pd.read_csv(csv_path)
            
            # Load corresponding Mask
            mask_filename = os.path.basename(csv_path).replace('.csv', '.png')
            mask_path = os.path.join(mask_dir, mask_filename)
            
            if not os.path.exists(mask_path):
                print(f"Mask missing for {csv_path}")
                continue
                
            mask = Image.open(mask_path)
            mask_arr = np.array(mask)
            
            # Check each bubble in the sample
            # Skip background (value 0)
            bubbles_df = df[df['pixel_value'] != 0]
            
            for _, row in bubbles_df.iterrows():
                pixel_val = row['pixel_value']
                source_name = row['source_bubble']
                
                # 1. Get Original Area
                if source_name in bubble_area_cache:
                    original_area = bubble_area_cache[source_name]
                else:
                    source_path = os.path.join(unique_dir, source_name)
                    if not os.path.exists(source_path):
                        print(f"Source bubble missing: {source_name}")
                        continue
                    src_img = Image.open(source_path)
                    src_arr = np.array(src_img) > 128
                    original_area = np.count_nonzero(src_arr)
                    bubble_area_cache[source_name] = original_area
                
                # 2. Get Visible Area from Mask
                visible_area = np.count_nonzero(mask_arr == pixel_val)
                
                total_bubbles += 1
                
                # 3. Check Ratio
                ratio = visible_area / original_area
                
                if ratio < 0.1:
                    msg = f"Violation in {mask_filename} (ID {pixel_val}): Visible Ratio {ratio:.2f} < 0.1"
                    # print(msg)
                    violations += 1
                    violation_list.append(msg)
                    
        except Exception as e:
            print(f"Error processing {csv_path}: {e}")
            
    print(f"\nVerification Complete.")
    print(f"Total Bubbles Checked: {total_bubbles}")
    print(f"Violations Found (Visible < 10%): {violations}")
    print(f"Violation Rate: {violations/total_bubbles*100:.2f}%")
    
    if violations > 0:
        print("\n--- Violation List ---")
        for v in violation_list:
            print(v)

# %% [markdown]
# # 4. Search for METRIC (m/pixel) of current dataset

# %%
# --- Modularized Evaluation Functions ---

def load_rdc_model(model_path):
    try:
        model = tf.keras.models.load_model(model_path)
        print("Model loaded successfully.")
        return model
    except Exception as e:
        print(f"Error loading model: {e}")
        return None

def get_gt_properties(source_path, metric):
    if not os.path.exists(source_path):
        return None
        
    src_img = Image.open(source_path)
    src_arr = np.array(src_img) > 128
    
    # Create GT RDObj
    gt_mask = np.zeros_like(src_arr, dtype=int)
    gt_mask[src_arr] = 1
    
    gt_rdc = RDObj(1, 64)
    gt_rdc.generateRD_manual(gt_mask)
    
    gt_bubble_obj = Bubble(gt_rdc.points, metric, ID=1)
    
    if gt_bubble_obj.Diameter is None:
        return None
        
    area = np.pi * (gt_bubble_obj.Major/2) * (gt_bubble_obj.Minor/2)
    return area

def evaluate_sample(csv_path, mask_dir, unique_dir, model, metric):
    try:
        df = pd.read_csv(csv_path)
        mask_filename = os.path.basename(csv_path).replace('.csv', '.png')
        mask_path = os.path.join(mask_dir, mask_filename)
        
        if not os.path.exists(mask_path):
            return []
            
        labels = np.array(Image.open(mask_path))
        predicted_bubbles = HiddenReco(labels, metric, useRDC=True, model=model, boolPlot=False)
        
        sample_accs = []
        
        for pred_bubble in predicted_bubbles:
            bubble_id = pred_bubble.ID
            matches = df[df['pixel_value'] == bubble_id]
            if len(matches) == 0: continue
                
            source_name = matches.iloc[0]['source_bubble']
            source_path = os.path.join(unique_dir, source_name)
            
            gt_area = get_gt_properties(source_path, metric)
            if gt_area is None: continue
            
            pred_area = np.pi * (pred_bubble.Major/2) * (pred_bubble.Minor/2)
            
            if max(pred_area, gt_area) == 0:
                acc = 0
            else:
                acc = min(pred_area, gt_area) / max(pred_area, gt_area)
                
            if not np.isnan(acc):
                sample_accs.append(acc)
                
        return sample_accs
        
    except Exception as e:
        print(f"Error processing {csv_path}: {e}")
        return []

def evaluate_rdc_dataset(rdc_dir, unique_dir, model_path, metric, num_samples=100):
    print(f"Evaluating RDC model on {num_samples} samples with Metric={metric}...")
    
    model = load_rdc_model(model_path)
    if model is None: return
        
    mask_dir = os.path.join(rdc_dir, 'Masks')
    csv_files = glob.glob(os.path.join(mask_dir, '*.csv'))
    
    if len(csv_files) == 0:
        print("No data found.")
        return

    selected_files = random.sample(csv_files, min(len(csv_files), num_samples))
    
    all_accuracies = []
    
    for csv_path in tqdm(selected_files):
        sample_accs = evaluate_sample(csv_path, mask_dir, unique_dir, model, metric)
        if sample_accs:
            all_accuracies.append(np.mean(sample_accs))
            
    print(f"\nEvaluation Complete.")
    if len(all_accuracies) > 0:
        print(f"Mean Area Accuracy (RDObj-based): {np.nanmean(all_accuracies):.4f}")
    else:
        print("No valid accuracies computed.")

# %% [markdown]
# 4.1 Determine optimal metric for the current dataset

# %%
def optimize_metric(rdc_dir, unique_dir, model_path):
    print("Starting Metric Optimization...")
    
    # 1. Load Model
    model = load_rdc_model(model_path)
    if model is None: return
    
    # 2. Select Fixed Samples
    mask_dir = os.path.join(rdc_dir, 'Masks')
    csv_files = glob.glob(os.path.join(mask_dir, '*.csv'))
    
    if len(csv_files) == 0:
        print("No data found.")
        return

    # Fix seed for reproducibility
    random.seed(42)
    selected_files = random.sample(csv_files, min(len(csv_files), 2000))
    print(f"Selected {len(selected_files)} fixed samples.")
    
    # 3. Define Metric Range
    # 1.0E-5 to 9.9E-5, step 0.1E-5
    metrics = np.arange(5.0, 6.5, 0.1) * 1e-2
    results = []
    
    print(f"Testing {len(metrics)} metric values...")
    
    for metric in tqdm(metrics):
        all_accuracies = []
        for csv_path in selected_files:
            sample_accs = evaluate_sample(csv_path, mask_dir, unique_dir, model, metric)
            if sample_accs:
                all_accuracies.append(np.mean(sample_accs))
        
        if all_accuracies:
            mean_acc = np.nanmean(all_accuracies)
            results.append((metric, mean_acc))
        else:
            results.append((metric, 0))
            
    # 4. Plot Results
    metrics_val = [r[0] for r in results]
    accuracies_val = [r[1] for r in results]
    
    best_idx = np.argmax(accuracies_val)
    best_metric = metrics_val[best_idx]
    best_acc = accuracies_val[best_idx]
    
    print(f"\nOptimization Complete.")
    print(f"Best Metric: {best_metric:.2e}")
    print(f"Best Accuracy: {best_acc:.4f}")
    
    plt.figure(figsize=(12, 6))
    plt.plot(metrics_val, accuracies_val, marker='o', linestyle='-', markersize=4)
    plt.axvline(x=best_metric, color='r', linestyle='--', label=f'Best: {best_metric:.2e}')
    plt.title('Mean Area Accuracy vs. Metric')
    plt.xlabel('Metric (m/pixel)')
    plt.ylabel('Mean Area Accuracy')
    plt.grid(True)
    plt.legend()
    plt.show()

# %% [markdown]
# # 5. Create Dataset for RDC Model
#   - Input, Output: Vector, each containing 64 values corresponding to the distance from center pixel to bubble edge, in meters
#   - Input generation: From synthetic image, determine 64 values for each bubble
#   - Input generation: From synthetic image, referencing the unmerged image (complete bubble), determine 64 rays based on this image

# %%
def generate_training_data(rdc_dir, unique_dir, metric=5.3E-2):
    print("Generating RDC Training Data (No Rotation)...")
    mask_dir = os.path.join(rdc_dir, 'Masks')
    output_dir = os.path.join(rdc_dir, 'Array-64-'+ str(metric)+'v2')
    if not os.path.exists(output_dir): os.makedirs(output_dir)
    
    csv_files = glob.glob(os.path.join(mask_dir, '*.csv'))
    X_data = []; Y_data = []
    
    def get_bubble_crop(bubble_arr):
        rows, cols = np.nonzero(bubble_arr)
        if len(rows) == 0: return None
        min_r, max_r = rows.min(), rows.max()
        min_c, max_c = cols.min(), cols.max()
        return bubble_arr[min_r:max_r+1, min_c:max_c+1]

    for csv_path in tqdm(csv_files):
        try:
            df = pd.read_csv(csv_path)
            mask_filename = os.path.basename(csv_path).replace('.csv', '.png')
            mask_path = os.path.join(mask_dir, mask_filename)
            if not os.path.exists(mask_path): continue
            labels = np.array(Image.open(mask_path))
            
            for bubble_id in range(1, np.max(labels) + 1):
                matches = df[df['pixel_value'] == bubble_id]
                if len(matches) == 0: continue
                source_name = matches.iloc[0]['source_bubble']
                r_pos = int(matches.iloc[0]['r'])
                c_pos = int(matches.iloc[0]['c'])
                
                source_path = os.path.join(unique_dir, source_name)
                if not os.path.exists(source_path): continue
                src_img = Image.open(source_path)
                src_arr = np.array(src_img) > 128
                
                visible_area = np.count_nonzero(labels == bubble_id)
                original_area = np.count_nonzero(src_arr)
                if original_area == 0 or visible_area / original_area < 0.1: continue
                
                rdc_input = RDObj(bubble_id, 64)
                rdc_input.generateRD_manual(labels)
                if rdc_input.center is None: continue
                x_dists = rdc_input.transformRDToArray(metric)
                
                full_crop = get_bubble_crop(src_arr)
                if full_crop is None: continue
                pad = 10
                padded_crop = np.pad(full_crop.astype(int), pad, mode='constant', constant_values=0)
                
                input_center_global = rdc_input.center
                local_y = input_center_global[0] - r_pos + pad
                local_x = input_center_global[1] - c_pos + pad
                local_center = (local_y, local_x)
                
                rdc_target = RDObj(1, 64, center=local_center)
                rdc_target.generateRD_manual(padded_crop)
                if rdc_target.center is None: continue
                y_dists = rdc_target.transformRDToArray(metric)
                
                X_data.append(x_dists)
                Y_data.append(y_dists)
        except: continue
            
    X_arr = np.array(X_data); Y_arr = np.array(Y_data)
    np.save(os.path.join(output_dir, 'X_train.npy'), X_arr)
    np.save(os.path.join(output_dir, 'Y_train.npy'), Y_arr)
    print(f"Done. {len(X_arr)} samples.")

# %%
def generate_training_data(rdc_dir, unique_dir, metric=5.3E-2):
    print("Generating RDC Training Data (Filtered Centers)...")
    mask_dir = os.path.join(rdc_dir, 'Masks')
    output_dir = os.path.join(rdc_dir, 'Array-64-'+ str(metric)+'v3')
    if not os.path.exists(output_dir): os.makedirs(output_dir)
    
    csv_files = glob.glob(os.path.join(mask_dir, '*.csv'))
    X_data = []; Y_data = []
    
    def get_bubble_crop(bubble_arr):
        rows, cols = np.nonzero(bubble_arr)
        if len(rows) == 0: return None
        min_r, max_r = rows.min(), rows.max()
        min_c, max_c = cols.min(), cols.max()
        return bubble_arr[min_r:max_r+1, min_c:max_c+1]

    for csv_path in tqdm(csv_files):
        try:
            df = pd.read_csv(csv_path)
            mask_filename = os.path.basename(csv_path).replace('.csv', '.png')
            mask_path = os.path.join(mask_dir, mask_filename)
            if not os.path.exists(mask_path): continue
            labels = np.array(Image.open(mask_path))
            
            for bubble_id in range(1, np.max(labels) + 1):
                matches = df[df['pixel_value'] == bubble_id]
                if len(matches) == 0: continue
                source_name = matches.iloc[0]['source_bubble']
                r_pos = int(matches.iloc[0]['r'])
                c_pos = int(matches.iloc[0]['c'])
                
                source_path = os.path.join(unique_dir, source_name)
                if not os.path.exists(source_path): continue
                src_img = Image.open(source_path)
                src_arr = np.array(src_img) > 128
                
                visible_area = np.count_nonzero(labels == bubble_id)
                original_area = np.count_nonzero(src_arr)
                if original_area == 0 or visible_area / original_area < 0.1: continue
                
                rdc_input = RDObj(bubble_id, 64)
                rdc_input.generateRD_manual(labels)
                
                # --- LỌC CÁC TRƯỜNG HỢP TÂM SAI ---
                if rdc_input.center is None: continue
                
                # Lấy tọa độ tâm
                cy, cx = int(rdc_input.center[0]), int(rdc_input.center[1])
                
                # 1. Kiểm tra biên (để tránh lỗi index)
                if not (0 <= cy < labels.shape[0] and 0 <= cx < labels.shape[1]):
                    continue
                
                # 2. Kiểm tra giá trị pixel tại tâm
                # Nếu != bubble_id tức là tâm nằm ở nền đen (0) hoặc đè lên bọt khác
                if labels[cy, cx] != bubble_id:
                    continue
                # ----------------------------------
                
                x_dists = rdc_input.transformRDToArray(metric)
                
                full_crop = get_bubble_crop(src_arr)
                if full_crop is None: continue
                pad = 10
                padded_crop = np.pad(full_crop.astype(int), pad, mode='constant', constant_values=0)
                
                input_center_global = rdc_input.center
                local_y = input_center_global[0] - r_pos + pad
                local_x = input_center_global[1] - c_pos + pad
                local_center = (local_y, local_x)
                
                rdc_target = RDObj(1, 64, center=local_center)
                rdc_target.generateRD_manual(padded_crop)
                if rdc_target.center is None: continue
                y_dists = rdc_target.transformRDToArray(metric)
                
                X_data.append(x_dists)
                Y_data.append(y_dists)
        except: continue
            
    X_arr = np.array(X_data); Y_arr = np.array(Y_data)
    np.save(os.path.join(output_dir, 'X_train.npy'), X_arr)
    np.save(os.path.join(output_dir, 'Y_train.npy'), Y_arr)
    print(f"Generation Done. Confirmed {len(X_arr)} valid samples.")

# %%
# 1. Statistics
df_stats = load_data(SOURCE_DIR)
#plot_pixel_counts(df_stats)
#plot_dimensions(df_stats)
print_summary(df_stats)
# Out:
# Loading data...
# Processing alpha_0.025...
# 100%|██████████| 1470/1470 [00:16<00:00, 88.31it/s]
# Processing alpha_0.05...
# 100%|██████████| 2728/2728 [00:33<00:00, 80.99it/s]
# Processing alpha_0.075...
# 100%|██████████| 4140/4140 [00:51<00:00, 79.68it/s]
# Processing alpha_0.1...
# 100%|██████████| 5569/5569 [01:09<00:00, 80.55it/s]
# --- Statistics Summary ---
#         pixel_count         width        height
# count  13907.000000  13907.000000  13907.000000
# mean    3534.150859     90.940318     51.285324
# std     2073.861710     31.052375     16.783162
# min      711.000000     36.000000     19.000000
# 25%     1980.500000     69.000000     39.000000
# 50%     2593.000000     80.000000     47.000000
# 75%     5290.500000    117.000000     63.000000
# max     9914.000000    196.000000    121.000000
#
# --- Summary by Alpha (Mean) ---
#        pixel_count      width     height
# alpha
# 0.025  3464.174830  89.781633  50.755102
# 0.05   3577.781158  91.493402  51.473607
# 0.075  3543.331884  91.227295  51.251449
# 0.1    3524.424134  90.761896  51.358233
#
# --- Width Statistics by Alpha ---
#        min  max       mean
# alpha
# 0.025   36  196  89.781633
# 0.05    36  194  91.493402
# 0.075   36  195  91.227295
# 0.1     36  194  90.761896
#
# --- Height Statistics by Alpha ---
#        min  max       mean
# alpha
# 0.025   21  121  50.755102
# 0.05    19  117  51.473607
# 0.075   20  121  51.251449
# 0.1     21  120  51.358233

# %%
# 2. Generation
generate_images(SOURCE_DIR, DEST_DIR)
# Out:
# Starting image generation...
# Generating images for alpha_0.025...
# 100%|██████████| 50/50 [00:36<00:00,  1.38it/s]
# Generating images for alpha_0.05...
# 100%|██████████| 50/50 [01:05<00:00,  1.30s/it]
# Generating images for alpha_0.075...
# 100%|██████████| 50/50 [00:44<00:00,  1.12it/s]
# Generating images for alpha_0.1...
# 100%|██████████| 50/50 [00:30<00:00,  1.64it/s]
# Generation Complete! Generated 13907 images.

# %%
# 3. Verification
verify_generation(SOURCE_DIR, DEST_DIR)
# Out:
# Starting verification...
# Verifying alpha_0.025...
# 100%|██████████| 1470/1470 [00:18<00:00, 79.73it/s]
# Verifying alpha_0.05...
# 100%|██████████| 2728/2728 [00:31<00:00, 87.63it/s]
# Verifying alpha_0.075...
#  26%|██▋       | 1087/4140 [00:12<00:34, 89.27it/s]
# Mismatch Pixel Count 20_52.png: Img=2308, CSV=2307
# 100%|██████████| 4140/4140 [00:46<00:00, 89.86it/s]
# Verifying alpha_0.1...
# 100%|██████████| 5569/5569 [00:58<00:00, 95.68it/s]
# Verification Complete!
# Total Checked: 13907
# Errors Found: 1

# %%
# 4. Duplicate Detection
check_duplicates(DEST_DIR)
# Out:
# Checking for duplicates...
# Scanning alpha_0.025...
# 100%|██████████| 1470/1470 [00:00<00:00, 30584.23it/s]
# Scanning alpha_0.05...
# 100%|██████████| 2728/2728 [00:00<00:00, 32829.39it/s]
# Scanning alpha_0.075...
# 100%|██████████| 4140/4140 [00:00<00:00, 31431.37it/s]
# Scanning alpha_0.1...
# 100%|██████████| 5569/5569 [00:00<00:00, 31515.91it/s]
# Found 3485 groups of duplicates.
#
# Duplicate Groups:
# Hash: 02fc943844c39edc18ff966dfaef6fd3
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_0.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\9_13.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\11_59.png
# --------------------
# Hash: 2007669230c610f3bf97c20db63673db
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_1.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.05\12_26.png
# --------------------
# Hash: 3a0c4a8391f98cb921e26f0071d4d26a
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_10.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\5_78.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\15_77.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\49_38.png
# --------------------
# Hash: 706ff6c076dd9500c984adf43164d9ed
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_12.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\26_28.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\2_58.png
# --------------------
# Hash: a78c19494b051cb490cb92548d6105ed
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_13.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.05\44_30.png
# --------------------
# Hash: 45b8b23630b24250d7d367d9b618e69e
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_17.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\30_16.png
# --------------------
# Hash: 7af2a727c3cb20d264a9037efd34e8ec
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_18.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\35_77.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\33_29.png
# --------------------
# Hash: c085a200427dae68ac51c814accbbc87
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_19.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\31_12.png
# --------------------
# Hash: 7ce9cea5299b15550ea1cf7fe4a465c4
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_2.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\47_11.png
# --------------------
# Hash: d3e76c979c9e6065c1281f50d015966e
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_22.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\27_54.png
# --------------------
# Hash: 2f24c6ed5418e86fb2d02568fc56f079
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_24.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\24_49.png
# --------------------
# Hash: d0bce1ffdb7658f721f075acec677c71
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_26.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\2_85.png
# --------------------
# Hash: 92588f466433bce1ad1f14f94cde4905
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_27.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\34_13.png
# --------------------
# Hash: b4a91c8c3c5e38f1005e81aa228b32d6
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_28.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\45_85.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\4_67.png
# --------------------
# Hash: 9d1ba33c9ff489382f82414fbfd431dd
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_3.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.05\16_26.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\45_109.png
# --------------------
# Hash: f377bd1f0c2e1c8600c6f11d0f1fd5fd
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_4.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.05\37_10.png
# --------------------
# Hash: d3318adf08c411bb52d33600dd5e2144
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_5.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.05\35_39.png
# --------------------
# Hash: fe377839f2d52aa7d6e79e2d9057ab33
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_7.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.05\47_57.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.075\1_61.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\33_61.png
# --------------------
# Hash: a12b43fd9019209907262d256524bdc0
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\0_8.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\29_88.png
# --------------------
# Hash: a2e4c80120c080b21a6a65026817889c
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\10_1.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\40_65.png
# --------------------
# Hash: ce4dbb4d4577613a205ee2ec15081b68
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.025\10

#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\5_27.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\7_14.png
# --------------------
# Hash: ac70d9004cc10d2439a7e22ad30f6437
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\6_119.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\6_83.png
# --------------------
# Hash: 8d1c94e39f7dbfefda3a36814a18e111
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\6_126.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\6_98.png
# --------------------
# Hash: 97022c5f8ff5b0482aa72c3a45d78fe2
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\6_6.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\6_89.png
# --------------------
# Hash: 9f163e09e7fbe90e43159d3b74664d2a
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\7_20.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\9_43.png
# --------------------
# Hash: a40f7695d649efd8c9193e284f649a38
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\7_54.png
#   - e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\data\RDC\Synth_Reconstructed\alpha_0.1\9_42.png
# --------------------

# %%
# 5. Filter Unique
filter_unique_bubbles(DEST_DIR, UNIQUE_DIR)
# Out:
# Filtering unique bubbles...
# Scanning alpha_0.025...
# 100%|██████████| 1470/1470 [00:00<00:00, 3124.99it/s]
# Scanning alpha_0.05...
# 100%|██████████| 2728/2728 [00:00<00:00, 3304.99it/s]
# Scanning alpha_0.075...
# 100%|██████████| 4140/4140 [00:01<00:00, 3815.13it/s]
# Scanning alpha_0.1...
# 100%|██████████| 5569/5569 [00:01<00:00, 5098.31it/s]
# Filtering Complete!
# Total Unique Bubbles: 9263

# %%
# 6. RDC Generation
generate_rdc_data(UNIQUE_DIR, RDC_DIR, num_samples=60000)
# Out:
# Generating RDC data (Corrected User Algo - With Rotation)...
# Loading bubbles: 100%|██████████| 9263/9263 [01:17<00:00, 118.97it/s]
# Loaded 9263 unique bubbles.
# 100%|██████████| 60000/60000 [03:28<00:00, 288.23it/s]

# %%
# 7. Geometric Verification
verify_geometry(RDC_DIR, UNIQUE_DIR, num_samples_to_check=1000)
# Out:
# Verifying geometric constraints on 1000 random samples...
# 100%|██████████| 1000/1000 [00:22<00:00, 45.18it/s]
# Verification Complete.
# Total Bubbles Checked: 2422
# Violations Found (Visible < 10%): 0
# Violation Rate: 0.00%

# %%
visualize_single_sample_rays(RDC_DIR, UNIQUE_DIR)
# Out:
# Selected Sample: fixed_rdc_21249.png

# %%
# 8. Model Evaluation (Modular)
evaluate_rdc_dataset(RDC_DIR, UNIQUE_DIR, MODEL_PATH, METRIC, num_samples=100)
# Out:
# Evaluating RDC model on 100 samples with Metric=5.2e-05...
# Model loaded successfully.
# 100%|██████████| 100/100 [00:12<00:00,  8.33it/s]
# Evaluation Complete.
# Mean Area Accuracy (RDObj-based): 0.8097

# %%
# 9. Metric Optimization
optimize_metric(RDC_DIR, UNIQUE_DIR, MODEL_PATH)
# Out:
# Starting Metric Optimization...
# Model loaded successfully.
# Selected 2000 fixed samples.
# Testing 30 metric values...
# 100%|██████████| 30/30 [1:41:57<00:00, 203.90s/it]
# Optimization Complete.
# Best Metric: 6.20e-05
# Best Accuracy: 0.8141

# %%
# 10. Generate Training Data
generate_training_data(RDC_DIR, UNIQUE_DIR, metric=6.2E-2)
# Out:
# Generating RDC Training Data (Filtered Centers)...
# 100%|██████████| 60000/60000 [36:08<00:00, 27.66it/s]
# Generation Done. Confirmed 129411 valid samples.
