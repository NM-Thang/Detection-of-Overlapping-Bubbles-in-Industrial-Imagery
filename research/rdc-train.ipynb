# %% [markdown]
# # RDC Model Training
#
# This notebook trains the Radial Deformation Correction (RDC) model using synthetic datasets.
#
# **Workflows:**
# 1. **Data Loading**: Loads pre-generated synthetic training data (X, Y) in meters.
# 2. **Model Architecture**: Builds a dense neural network for deformation correction.
# 3. **Training**: Optimizes the model using MSE loss and Adam optimizer.
# 4. **Evaluation**: Plots training history and evaluates model performance on validation data.
#
# **Input**: `data/RDC/Synthetic_RDC`
# **Output**: `Models/RDC`

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
#from sklearn.model_selection import train_test_split
import datetime

# %%
# --- Configuration ---
DATA_DIR = os.path.abspath('data/RDC/Synthetic_RDC/Array-64-0.052')
MODEL_SAVE_DIR = os.path.abspath('Models/RDC')
LOG_DIR = os.path.abspath('logs/rdc')

# Hyperparameters (from Paper)
INPUT_DIM = 64
HIDDEN_DIM = 64
OUTPUT_DIM = 64
NUM_HIDDEN_LAYERS = 3
LEARNING_RATE = 1e-4
BATCH_SIZE = 1400
EPOCHS = 1000
VALIDATION_SPLIT = 0.1 # ~15,000 / 150,000 samples

# %%
def load_dataset(data_dir):
    print("Loading dataset...")
    x_path = os.path.join(data_dir, 'X_train.npy')
    y_path = os.path.join(data_dir, 'Y_train.npy')
    
    if not os.path.exists(x_path) or not os.path.exists(y_path):
        raise FileNotFoundError(f"Data not found in {data_dir}")
    
    # Use Meters (Original Units)
    X = np.load(x_path)
    Y = np.load(y_path)
    
    print(f"Loaded X: {X.shape} (Units: Meters)")
    print(f"Loaded Y: {Y.shape} (Units: Meters)")
    # Shuffle the dataset
    print("Shuffling dataset...")
    indices = np.random.permutation(X.shape[0])
    X = X[indices]
    Y = Y[indices]

    return X, Y

# %%
def build_rdc_model(input_dim, hidden_dim, output_dim, num_hidden_layers, learning_rate):
    print("Building RDC Model...")
    model = models.Sequential()
    
    # Input Layer
    model.add(layers.InputLayer(input_shape=(input_dim,)))
    
    # Hidden Layers
    for _ in range(num_hidden_layers):
        model.add(layers.Dense(hidden_dim, activation='relu'))
        
    # Output Layer
    model.add(layers.Dense(output_dim))
    
    # Compile
    optimizer = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
    
    model.summary()
    return model

# %%
def train_model(model, X, Y, batch_size, epochs, val_split, log_dir, save_dir):
    print("Starting Training...")
    
    # Callbacks
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
        
    checkpoint_path = os.path.join(save_dir, 'rdc_model_mm.h5')
    
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_path,
            save_best_only=True,
            monitor='val_loss',
            mode='min',
            verbose=1
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            min_delta=0.001,
            patience=100,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=20,
            min_lr=1e-6,
            verbose=1
        ),
        tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=3)
    ]
    
    history = model.fit(
        X, Y,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=val_split,
        callbacks=callbacks,
        verbose=1
    )
    
    return history

# %%
def plot_training_history(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    mae = history.history['mae']
    val_mae = history.history['val_mae']
    epochs_range = range(len(loss))

    plt.figure(figsize=(14, 6))

    # Plot Loss (MSE)
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss (MSE) [m^2]')
    plt.xlabel('Epochs')
    plt.ylabel('MSE (m^2)')
    plt.grid(True)

    # Plot MAE
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, mae, label='Training MAE')
    plt.plot(epochs_range, val_mae, label='Validation MAE')
    plt.legend(loc='upper right')
    plt.title('Training and Validation MAE [m]')
    plt.xlabel('Epochs')
    plt.ylabel('MAE (m)')
    plt.grid(True)

    plt.show()

# %%
def evaluate_predictions(model, X, Y, num_samples=5):
    print("Evaluating sample predictions...")
    
    # Predict
    indices = np.random.choice(len(X), num_samples, replace=False)
    X_sample = X[indices]
    Y_sample = Y[indices]
    Y_pred = model.predict(X_sample)
    
    # Plot
    # Append first point to end to close the loop
    angles = np.linspace(0, 2*np.pi, 64, endpoint=False)
    angles = np.append(angles, angles[0])
    
    for i in range(num_samples):
        plt.figure(figsize=(6, 6))
        ax = plt.subplot(111, projection='polar')
        
        # Prepare data for closed loop plot
        x_plot = np.append(X_sample[i], X_sample[i][0])
        y_plot = np.append(Y_sample[i], Y_sample[i][0])
        pred_plot = np.append(Y_pred[i], Y_pred[i][0])
        
        # Input (Occluded)
        ax.plot(angles, x_plot, 'b-', label='Input (Occluded)', linewidth=1.5)
        
        # Target (Ground Truth)
        ax.plot(angles, y_plot, 'g--', label='Target (GT)', linewidth=1.5)
        
        # Prediction
        ax.plot(angles, pred_plot, 'r:', label='Prediction', linewidth=2)
        
        ax.set_title(f'Sample {indices[i]} (Units: Meters)')
        ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
        plt.show()

# %%
def calculate_area_accuracy(model, X, Y):
    print("Calculating Mean Area Accuracy...")
    Y_pred = model.predict(X)
    
    # Calculate Area from Radial Distances (Polygon Formula)
    # Area = 0.5 * sum(r[i] * r[i+1] * sin(d_theta))
    k = Y.shape[1]
    d_theta = 2 * np.pi / k
    sin_d_theta = np.sin(d_theta)
    
    # We need to roll Y to get r[i+1]
    # Axis 1 is the radial dimension
    Y_rolled = np.roll(Y, -1, axis=1)
    Y_pred_rolled = np.roll(Y_pred, -1, axis=1)
    
    # Compute areas for all samples at once
    # Shape: (N, K) -> sum -> (N,)
    area_gt = 0.5 * np.sum(Y * Y_rolled * sin_d_theta, axis=1)
    area_pred = 0.5 * np.sum(Y_pred * Y_pred_rolled * sin_d_theta, axis=1)
    
    # Avoid division by zero
    area_gt = np.maximum(area_gt, 1e-10)
    area_pred = np.maximum(area_pred, 1e-10)
    
    # Calculate Ratio (Accuracy)
    # Acc = min(A_pred, A_gt) / max(A_pred, A_gt)
    accuracies = np.minimum(area_pred, area_gt) / np.maximum(area_pred, area_gt)
    
    mean_acc = np.mean(accuracies)
    print(f"Mean Area Accuracy: {mean_acc:.4f} ({mean_acc*100:.2f}%)")
    return mean_acc

# %%
# 1. Load Data
if os.path.exists(DATA_DIR):
    X, Y = load_dataset(DATA_DIR)
else:
    print(f"Data directory {DATA_DIR} does not exist. Please run rdc-data.ipynb first.")
# Out:
# Loading dataset...
# Loaded X: (150122, 64) (Units: Meters)
# Loaded Y: (150122, 64) (Units: Meters)
# Shuffling dataset...

# %%
# 2. Build Model
model = build_rdc_model(
    input_dim=INPUT_DIM,
    hidden_dim=HIDDEN_DIM,
    output_dim=OUTPUT_DIM,
    num_hidden_layers=NUM_HIDDEN_LAYERS,
    learning_rate=LEARNING_RATE
)
# Out:
# Building RDC Model...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# =================================================================
# Total params: 16,640
# Trainable params: 16,640
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 3. Train Model
log_dir = os.path.join(LOG_DIR, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
history = train_model(
    model, X, Y,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    val_split=VALIDATION_SPLIT,
    log_dir=log_dir,
    save_dir=MODEL_SAVE_DIR
)
# Out:
# Starting Training...
# Epoch 1/1000
# 97/97 [==============================] - 1s 6ms/step - loss: 2.8581 - mae: 1.5203 - val_loss: 1.6284 - val_mae: 1.0576
#
# Epoch 00001: val_loss improved from inf to 1.62841, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 2/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 1.1461 - mae: 0.8370 - val_loss: 0.3224 - val_mae: 0.4097
#
# Epoch 00002: val_loss improved from 1.62841 to 0.32240, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 3/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.2550 - mae: 0.3530 - val_loss: 0.1481 - val_mae: 0.2566
#
# Epoch 00003: val_loss improved from 0.32240 to 0.14808, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 4/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.1423 - mae: 0.2475 - val_loss: 0.1257 - val_mae: 0.2300
#
# Epoch 00004: val_loss improved from 0.14808 to 0.12572, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 5/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1260 - mae: 0.2272 - val_loss: 0.1141 - val_mae: 0.2161
#
# Epoch 00005: val_loss improved from 0.12572 to 0.11412, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 6/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1141 - mae: 0.2125 - val_loss: 0.1034 - val_mae: 0.2021
#
# Epoch 00006: val_loss improved from 0.11412 to 0.10339, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 7/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.1035 - mae: 0.1994 - val_loss: 0.0933 - val_mae: 0.1889
#
# Epoch 00007: val_loss improved from 0.10339 to 0.09333, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 8/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0937 - mae: 0.1866 - val_loss: 0.0849 - val_mae: 0.1776
#
# Epoch 00008: val_loss improved from 0.09333 to 0.08488, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 9/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0856 - mae: 0.1751 - val_loss: 0.0779 - val_mae: 0.1669
#
# Epoch 00009: val_loss improved from 0.08488 to 0.07786, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 10/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0798 - mae: 0.1657 - val_loss: 0.0722 - val_mae: 0.1578
#
# Epoch 00010: val_loss improved from 0.07786 to 0.07224, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 11/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0745 - mae: 0.1569 - val_loss: 0.0679 - val_mae: 0.1510
#
# Epoch 00011: val_loss improved from 0.07224 to 0.06786, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 12/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0714 - mae: 0.1514 - val_loss: 0.0643 - val_mae: 0.1456
#
# Epoch 00012: val_loss improved from 0.06786 to 0.06428, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 13/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0667 - mae: 0.1449 - val_loss: 0.0610 - val_mae: 0.1402
#
# Epoch 00013: val_loss improved from 0.06428 to 0.06104, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 14/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0641 - mae: 0.1404 - val_loss: 0.0585 - val_mae: 0.1358
#
# Epoch 00014: val_loss improved from 0.06104 to 0.05854, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 15/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0613 - mae: 0.1362 - val_loss: 0.0566 - val_mae: 0.1334
#
# Epoch 00015: val_loss improved from 0.05854 to 0.05662, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 16/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0603 - mae: 0.1347 - val_loss: 0.0552 - val_mae: 0.1311
#
# Epoch 00016: val_loss improved from 0.05662 to 0.05517, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 17/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0573 - mae: 0.1316 - val_loss: 0.0539 - val_mae: 0.1301
#
# Epoch 00017: val_loss improved from 0.05517 to 0.05390, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 18/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0559 - mae: 0.1297 - val_loss: 0.0527 - val_mae: 0.1279
#
# Epoch 00018: val_loss improved from 0.05390 to 0.05275, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 19/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0551 - mae: 0.1285 - val_loss: 0.0517 - val_mae: 0.1256
#
# Epoch 00019: val_loss improved from 0.05275 to 0.05170, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 20/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0542 - mae: 0.1272 - val_loss: 0.0507 - val_mae: 0.1250
#
# Epoch 00020: val_loss improved from 0.05170 to 0.05067, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 21/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0535 - mae: 0.1257 - val_loss: 0.0497 - val_mae: 0.1232
#
# Epoch 00021: val_loss improved from 0.05067 to 0.04970, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 22/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0526 - mae: 0.1248 - val_loss: 0.0488 - val_mae: 0.1219
#
# Epoch 00022: val_loss improved from 0.04970 to 0.04883, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 23/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0510 - mae: 0.1229 - val_loss: 0.0480 - val_mae: 0.1215
#
# Epoch 00023: val_loss improved from 0.04883 to 0.04796, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 24/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0507 - mae: 0.1222 - val_loss: 0.0471 - val_mae: 0.1205
#
# Epoch 00024: val_loss improved from 0.04796 to 0.04713, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 25/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0483 - mae: 0.1198 - val_loss: 0.0463 - val_mae: 0.1196
#
# Epoch 00025: val_loss improved from 0.04713 to 0.04632, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 26/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0490 - mae: 0.1198 - val_loss: 0.0456 - val_mae: 0.1177
#
# Epoch 00026: val_loss improved from 0.04632 to 0.04557, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 27/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0481 - mae: 0.1180 - val_loss: 0.0449 - val_mae: 0.1164
#
# Epoch 00027: val_loss improved from 0.04557 to 0.04487, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 28/1000
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0467 - mae: 0.1169 - val_loss: 0.0443 - val_mae: 0.1152
#
# Epoch 00028: val_loss improved from 0.04487 to 0.04425, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 29/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0469 - mae: 0.1160 - val_loss: 0.0436 - val_mae: 0.1141
#
# Epoch 00029: val_loss improved from 0.04425 to 0.04360, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 30/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0459 - mae: 0.1149 - val_loss: 0.0430 - val_mae: 0.1136
#
# Epoch 00030: val_loss improved from 0.04360 to 0.04304, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 31/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0456 - mae: 0.1136 - val_loss: 0.0424 - val_mae: 0.1122
#
# Epoch 00031: val_loss improved from 0.04304 to 0.04243, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 32/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0445 - mae: 0.1125 - val_loss: 0.0419 - val_mae: 0.1114
#
# Epoch 00032: val_loss improved from 0.04243 to 0.04186, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 33/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0441 - mae: 0.1115 - val_loss: 0.0413 - val_mae: 0.1096
#
# Epoch 00033: val_loss improved from 0.04186 to 0.04131, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 34/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0434 - mae: 0.1105 - val_loss: 0.0408 - val_mae: 0.1099
#
# Epoch 00034: val_loss improved from 0.04131 to 0.04081, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 35/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0425 - mae: 0.1096 - val_loss: 0.0403 - val_mae: 0.1077
#
# Epoch 00035: val_loss improved from 0.04081 to 0.04031, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 36/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0423 - mae: 0.1087 - val_loss: 0.0398 - val_mae: 0.1077
#
# Epoch 00036: val_loss improved from 0.04031 to 0.03977, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 37/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0417 - mae: 0.1079 - val_loss: 0.0393 - val_mae: 0.1067
#
# Epoch 00037: val_loss improved from 0.03977 to 0.03928, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 38/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0410 - mae: 0.1065 - val_loss: 0.0389 - val_mae: 0.1049
#
# Epoch 00038: val_loss improved from 0.03928 to 0.03885, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 39/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0407 - mae: 0.1057 - val_loss: 0.0384 - val_mae: 0.1051
#
# Epoch 00039: val_loss improved from 0.03885 to 0.03844, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 40/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0400 - mae: 0.1043 - val_loss: 0.0379 - val_mae: 0.1027
#
# Epoch 00040: val_loss improved from 0.03844 to 0.03794, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 41/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0394 - mae: 0.1035 - val_loss: 0.0376 - val_mae: 0.1036
#
# Epoch 00041: val_loss improved from 0.03794 to 0.03762, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 42/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0393 - mae: 0.1028 - val_loss: 0.0372 - val_mae: 0.1017
#
# Epoch 00042: val_loss improved from 0.03762 to 0.03720, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 43/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0395 - mae: 0.1024 - val_loss: 0.0368 - val_mae: 0.1006
#
# Epoch 00043: val_loss improved from 0.03720 to 0.03679, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 44/1000
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0385 - mae: 0.1010 - val_loss: 0.0364 - val_mae: 0.1001
#
# Epoch 00044: val_loss improved from 0.03679 to 0.03643, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 45/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0389 - mae: 0.1006 - val_loss: 0.0361 - val_mae: 0.0992
#
# Epoch 00045: val_loss improved from 0.03643 to 0.03608, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 46/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0377 - mae: 0.0993 - val_loss: 0.0358 - val_mae: 0.0983
#
# Epoch 00046: val_loss improved from 0.03608 to 0.03579, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 47/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0379 - mae: 0.0991 - val_loss: 0.0355 - val_mae: 0.0980
#
# Epoch 00047: val_loss improved from 0.03579 to 0.03548, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 48/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0373 - mae: 0.0980 - val_loss: 0.0352 - val_mae: 0.0972
#
# Epoch 00048: val_loss improved from 0.03548 to 0.03522, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 49/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0370 - mae: 0.0974 - val_loss: 0.0349 - val_mae: 0.0959
#
# Epoch 00049: val_loss improved from 0.03522 to 0.03489, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 50/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0365 - mae: 0.0965 - val_loss: 0.0346 - val_mae: 0.0959
#
# Epoch 00050: val_loss improved from 0.03489 to 0.03464, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 51/1000
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0364 - mae: 0.0960 - val_loss: 0.0344 - val_mae: 0.0951
#
# Epoch 00051: val_loss improved from 0.03464 to 0.03439, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 52/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0357 - mae: 0.0951 - val_loss: 0.0342 - val_mae: 0.0942
#
# Epoch 00052: val_loss improved from 0.03439 to 0.03420, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 53/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0358 - mae: 0.0947 - val_loss: 0.0339 - val_mae: 0.0945
#
# Epoch 00053: val_loss improved from 0.03420 to 0.03392, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 54/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0358 - mae: 0.0944 - val_loss: 0.0337 - val_mae: 0.0935
#
# Epoch 00054: val_loss improved from 0.03392 to 0.03369, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 55/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0353 - mae: 0.0937 - val_loss: 0.0334 - val_mae: 0.0931
#
# Epoch 00055: val_loss improved from 0.03369 to 0.03345, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 56/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0352 - mae: 0.0933 - val_loss: 0.0332 - val_mae: 0.0924
#
# Epoch 00056: val_loss improved from 0.03345 to 0.03324, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 57/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0349 - mae: 0.0927 - val_loss: 0.0331 - val_mae: 0.0918
#
# Epoch 00057: val_loss improved from 0.03324 to 0.03309, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 58/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0347 - mae: 0.0924 - val_loss: 0.0328 - val_mae: 0.0915
#
# Epoch 00058: val_loss improved from 0.03309 to 0.03282, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 59/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0348 - mae: 0.0922 - val_loss: 0.0326 - val_mae: 0.0909
#
# Epoch 00059: val_loss improved from 0.03282 to 0.03265, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 60/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0344 - mae: 0.0916 - val_loss: 0.0325 - val_mae: 0.0909
#
# Epoch 00060: val_loss improved from 0.03265 to 0.03245, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 61/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0339 - mae: 0.0911 - val_loss: 0.0323 - val_mae: 0.0901
#
# Epoch 00061: val_loss improved from 0.03245 to 0.03227, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 62/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0336 - mae: 0.0904 - val_loss: 0.0321 - val_mae: 0.0896
#
# Epoch 00062: val_loss improved from 0.03227 to 0.03213, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 63/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0334 - mae: 0.0901 - val_loss: 0.0319 - val_mae: 0.0892
#
# Epoch 00063: val_loss improved from 0.03213 to 0.03193, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 64/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0336 - mae: 0.0901 - val_loss: 0.0318 - val_mae: 0.0893
#
# Epoch 00064: val_loss improved from 0.03193 to 0.03179, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 65/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0334 - mae: 0.0900 - val_loss: 0.0317 - val_mae: 0.0886
#
# Epoch 00065: val_loss improved from 0.03179 to 0.03166, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 66/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0325 - mae: 0.0889 - val_loss: 0.0315 - val_mae: 0.0904
#
# Epoch 00066: val_loss improved from 0.03166 to 0.03155, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 67/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0323 - mae: 0.0885 - val_loss: 0.0313 - val_mae: 0.0881
#
# Epoch 00067: val_loss improved from 0.03155 to 0.03126, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 68/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0324 - mae: 0.0884 - val_loss: 0.0311 - val_mae: 0.0877
#
# Epoch 00068: val_loss improved from 0.03126 to 0.03110, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 69/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0323 - mae: 0.0881 - val_loss: 0.0309 - val_mae: 0.0875
#
# Epoch 00069: val_loss improved from 0.03110 to 0.03095, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 70/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0321 - mae: 0.0877 - val_loss: 0.0308 - val_mae: 0.0867
#
# Epoch 00070: val_loss improved from 0.03095 to 0.03078, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 71/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0322 - mae: 0.0877 - val_loss: 0.0306 - val_mae: 0.0872
#
# Epoch 00071: val_loss improved from 0.03078 to 0.03064, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 72/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0318 - mae: 0.0874 - val_loss: 0.0306 - val_mae: 0.0874
#
# Epoch 00072: val_loss improved from 0.03064 to 0.03058, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 73/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0317 - mae: 0.0872 - val_loss: 0.0304 - val_mae: 0.0868
#
# Epoch 00073: val_loss improved from 0.03058 to 0.03037, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 74/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0316 - mae: 0.0866 - val_loss: 0.0303 - val_mae: 0.0865
#
# Epoch 00074: val_loss improved from 0.03037 to 0.03030, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 75/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0316 - mae: 0.0867 - val_loss: 0.0301 - val_mae: 0.0858
#
# Epoch 00075: val_loss improved from 0.03030 to 0.03013, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 76/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0317 - mae: 0.0864 - val_loss: 0.0300 - val_mae: 0.0857
#
# Epoch 00076: val_loss improved from 0.03013 to 0.02998, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 77/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0315 - mae: 0.0862 - val_loss: 0.0299 - val_mae: 0.0855
#
# Epoch 00077: val_loss improved from 0.02998 to 0.02988, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 78/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0310 - mae: 0.0857 - val_loss: 0.0297 - val_mae: 0.0849
#
# Epoch 00078: val_loss improved from 0.02988 to 0.02973, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 79/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0312 - mae: 0.0857 - val_loss: 0.0297 - val_mae: 0.0856
#
# Epoch 00079: val_loss improved from 0.02973 to 0.02967, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 80/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0312 - mae: 0.0855 - val_loss: 0.0295 - val_mae: 0.0845
#
# Epoch 00080: val_loss improved from 0.02967 to 0.02952, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 81/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0307 - mae: 0.0849 - val_loss: 0.0294 - val_mae: 0.0842
#
# Epoch 00081: val_loss improved from 0.02952 to 0.02938, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 82/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0307 - mae: 0.0848 - val_loss: 0.0293 - val_mae: 0.0841
#
# Epoch 00082: val_loss improved from 0.02938 to 0.02929, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 83/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0305 - mae: 0.0845 - val_loss: 0.0291 - val_mae: 0.0842
#
# Epoch 00083: val_loss improved from 0.02929 to 0.02915, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 84/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0303 - mae: 0.0844 - val_loss: 0.0291 - val_mae: 0.0836
#
# Epoch 00084: val_loss improved from 0.02915 to 0.02909, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 85/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0309 - mae: 0.0847 - val_loss: 0.0290 - val_mae: 0.0836
#
# Epoch 00085: val_loss improved from 0.02909 to 0.02900, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 86/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0304 - mae: 0.0842 - val_loss: 0.0289 - val_mae: 0.0840
#
# Epoch 00086: val_loss improved from 0.02900 to 0.02893, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 87/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0298 - mae: 0.0835 - val_loss: 0.0287 - val_mae: 0.0832
#
# Epoch 00087: val_loss improved from 0.02893 to 0.02874, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 88/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0296 - mae: 0.0831 - val_loss: 0.0287 - val_mae: 0.0828
#
# Epoch 00088: val_loss improved from 0.02874 to 0.02869, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 89/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0299 - mae: 0.0835 - val_loss: 0.0286 - val_mae: 0.0822
#
# Epoch 00089: val_loss improved from 0.02869 to 0.02858, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 90/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0297 - mae: 0.0831 - val_loss: 0.0285 - val_mae: 0.0824
#
# Epoch 00090: val_loss improved from 0.02858 to 0.02848, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 91/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0301 - mae: 0.0834 - val_loss: 0.0284 - val_mae: 0.0831
#
# Epoch 00091: val_loss improved from 0.02848 to 0.02838, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 92/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0300 - mae: 0.0834 - val_loss: 0.0284 - val_mae: 0.0821
#
# Epoch 00092: val_loss did not improve from 0.02838
# Epoch 93/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0291 - mae: 0.0824 - val_loss: 0.0282 - val_mae: 0.0816
#
# Epoch 00093: val_loss improved from 0.02838 to 0.02820, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 94/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0295 - mae: 0.0826 - val_loss: 0.0281 - val_mae: 0.0817
#
# Epoch 00094: val_loss improved from 0.02820 to 0.02812, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 95/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0294 - mae: 0.0823 - val_loss: 0.0281 - val_mae: 0.0813
#
# Epoch 00095: val_loss improved from 0.02812 to 0.02808, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 96/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0295 - mae: 0.0822 - val_loss: 0.0280 - val_mae: 0.0811
#
# Epoch 00096: val_loss improved from 0.02808 to 0.02796, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 97/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0291 - mae: 0.0817 - val_loss: 0.0279 - val_mae: 0.0809
#
# Epoch 00097: val_loss improved from 0.02796 to 0.02787, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 98/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0291 - mae: 0.0816 - val_loss: 0.0278 - val_mae: 0.0812
#
# Epoch 00098: val_loss improved from 0.02787 to 0.02780, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 99/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0291 - mae: 0.0821 - val_loss: 0.0277 - val_mae: 0.0809
#
# Epoch 00099: val_loss improved from 0.02780 to 0.02772, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 100/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0289 - mae: 0.0813 - val_loss: 0.0276 - val_mae: 0.0808
#
# Epoch 00100: val_loss improved from 0.02772 to 0.02763, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 101/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0284 - mae: 0.0807 - val_loss: 0.0276 - val_mae: 0.0800
#
# Epoch 00101: val_loss improved from 0.02763 to 0.02759, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 102/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0285 - mae: 0.0806 - val_loss: 0.0275 - val_mae: 0.0801
#
# Epoch 00102: val_loss improved from 0.02759 to 0.02751, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 103/1000
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0286 - mae: 0.0808 - val_loss: 0.0275 - val_mae: 0.0812
#
# Epoch 00103: val_loss improved from 0.02751 to 0.02750, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 104/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0287 - mae: 0.0810 - val_loss: 0.0274 - val_mae: 0.0798
#
# Epoch 00104: val_loss improved from 0.02750 to 0.02738, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 105/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0284 - mae: 0.0804 - val_loss: 0.0273 - val_mae: 0.0797
#
# Epoch 00105: val_loss improved from 0.02738 to 0.02729, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 106/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0281 - mae: 0.0800 - val_loss: 0.0272 - val_mae: 0.0806
#
# Epoch 00106: val_loss improved from 0.02729 to 0.02724, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 107/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0281 - mae: 0.0799 - val_loss: 0.0272 - val_mae: 0.0798
#
# Epoch 00107: val_loss improved from 0.02724 to 0.02720, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 108/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0283 - mae: 0.0802 - val_loss: 0.0271 - val_mae: 0.0798
#
# Epoch 00108: val_loss improved from 0.02720 to 0.02708, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 109/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0283 - mae: 0.0800 - val_loss: 0.0270 - val_mae: 0.0793
#
# Epoch 00109: val_loss improved from 0.02708 to 0.02703, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 110/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0281 - mae: 0.0797 - val_loss: 0.0270 - val_mae: 0.0791
#
# Epoch 00110: val_loss improved from 0.02703 to 0.02698, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 111/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0277 - mae: 0.0794 - val_loss: 0.0269 - val_mae: 0.0796
#
# Epoch 00111: val_loss improved from 0.02698 to 0.02692, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 112/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0280 - mae: 0.0794 - val_loss: 0.0270 - val_mae: 0.0791
#
# Epoch 00112: val_loss did not improve from 0.02692
# Epoch 113/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0280 - mae: 0.0791 - val_loss: 0.0268 - val_mae: 0.0784
#
# Epoch 00113: val_loss improved from 0.02692 to 0.02679, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 114/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0279 - mae: 0.0792 - val_loss: 0.0268 - val_mae: 0.0795
#
# Epoch 00114: val_loss did not improve from 0.02679
# Epoch 115/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0281 - mae: 0.0794 - val_loss: 0.0267 - val_mae: 0.0778
#
# Epoch 00115: val_loss improved from 0.02679 to 0.02669, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 116/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0275 - mae: 0.0789 - val_loss: 0.0267 - val_mae: 0.0785
#
# Epoch 00116: val_loss did not improve from 0.02669
# Epoch 117/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0278 - mae: 0.0788 - val_loss: 0.0266 - val_mae: 0.0784
#
# Epoch 00117: val_loss improved from 0.02669 to 0.02660, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 118/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0275 - mae: 0.0786 - val_loss: 0.0265 - val_mae: 0.0782
#
# Epoch 00118: val_loss improved from 0.02660 to 0.02650, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 119/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0272 - mae: 0.0783 - val_loss: 0.0265 - val_mae: 0.0781
#
# Epoch 00119: val_loss improved from 0.02650 to 0.02650, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 120/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0276 - mae: 0.0785 - val_loss: 0.0264 - val_mae: 0.0780
#
# Epoch 00120: val_loss improved from 0.02650 to 0.02637, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 121/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0275 - mae: 0.0784 - val_loss: 0.0264 - val_mae: 0.0778
#
# Epoch 00121: val_loss did not improve from 0.02637
# Epoch 122/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0278 - mae: 0.0785 - val_loss: 0.0263 - val_mae: 0.0775
#
# Epoch 00122: val_loss improved from 0.02637 to 0.02629, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 123/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0271 - mae: 0.0778 - val_loss: 0.0263 - val_mae: 0.0779
#
# Epoch 00123: val_loss improved from 0.02629 to 0.02625, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 124/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0271 - mae: 0.0778 - val_loss: 0.0262 - val_mae: 0.0777
#
# Epoch 00124: val_loss improved from 0.02625 to 0.02620, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 125/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0270 - mae: 0.0775 - val_loss: 0.0262 - val_mae: 0.0779
#
# Epoch 00125: val_loss improved from 0.02620 to 0.02620, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 126/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0274 - mae: 0.0778 - val_loss: 0.0261 - val_mae: 0.0774
#
# Epoch 00126: val_loss improved from 0.02620 to 0.02610, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 127/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0267 - mae: 0.0770 - val_loss: 0.0262 - val_mae: 0.0788
#
# Epoch 00127: val_loss did not improve from 0.02610
# Epoch 128/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0269 - mae: 0.0774 - val_loss: 0.0260 - val_mae: 0.0771
#
# Epoch 00128: val_loss improved from 0.02610 to 0.02601, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 129/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0270 - mae: 0.0774 - val_loss: 0.0260 - val_mae: 0.0773
#
# Epoch 00129: val_loss did not improve from 0.02601
# Epoch 130/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0268 - mae: 0.0772 - val_loss: 0.0259 - val_mae: 0.0769
#
# Epoch 00130: val_loss improved from 0.02601 to 0.02594, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 131/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0266 - mae: 0.0768 - val_loss: 0.0259 - val_mae: 0.0771
#
# Epoch 00131: val_loss improved from 0.02594 to 0.02594, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 132/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0270 - mae: 0.0770 - val_loss: 0.0259 - val_mae: 0.0763
#
# Epoch 00132: val_loss improved from 0.02594 to 0.02589, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 133/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0266 - mae: 0.0767 - val_loss: 0.0259 - val_mae: 0.0771
#
# Epoch 00133: val_loss did not improve from 0.02589
# Epoch 134/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0269 - mae: 0.0769 - val_loss: 0.0258 - val_mae: 0.0767
#
# Epoch 00134: val_loss improved from 0.02589 to 0.02580, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 135/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0268 - mae: 0.0767 - val_loss: 0.0257 - val_mae: 0.0761
#
# Epoch 00135: val_loss improved from 0.02580 to 0.02575, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 136/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0269 - mae: 0.0766 - val_loss: 0.0257 - val_mae: 0.0763
#
# Epoch 00136: val_loss improved from 0.02575 to 0.02570, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 137/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0265 - mae: 0.0762 - val_loss: 0.0257 - val_mae: 0.0764
#
# Epoch 00137: val_loss improved from 0.02570 to 0.02569, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 138/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0267 - mae: 0.0767 - val_loss: 0.0256 - val_mae: 0.0765
#
# Epoch 00138: val_loss improved from 0.02569 to 0.02564, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 139/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0263 - mae: 0.0761 - val_loss: 0.0256 - val_mae: 0.0761
#
# Epoch 00139: val_loss improved from 0.02564 to 0.02560, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 140/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0265 - mae: 0.0763 - val_loss: 0.0255 - val_mae: 0.0756
#
# Epoch 00140: val_loss improved from 0.02560 to 0.02552, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 141/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0264 - mae: 0.0760 - val_loss: 0.0255 - val_mae: 0.0759
#
# Epoch 00141: val_loss improved from 0.02552 to 0.02551, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 142/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0263 - mae: 0.0759 - val_loss: 0.0255 - val_mae: 0.0754
#
# Epoch 00142: val_loss did not improve from 0.02551
# Epoch 143/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0262 - mae: 0.0757 - val_loss: 0.0255 - val_mae: 0.0750
#
# Epoch 00143: val_loss improved from 0.02551 to 0.02545, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 144/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0260 - mae: 0.0757 - val_loss: 0.0254 - val_mae: 0.0754
#
# Epoch 00144: val_loss improved from 0.02545 to 0.02540, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 145/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0263 - mae: 0.0756 - val_loss: 0.0254 - val_mae: 0.0758
#
# Epoch 00145: val_loss improved from 0.02540 to 0.02540, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 146/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0259 - mae: 0.0754 - val_loss: 0.0254 - val_mae: 0.0761
#
# Epoch 00146: val_loss improved from 0.02540 to 0.02539, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 147/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0259 - mae: 0.0751 - val_loss: 0.0253 - val_mae: 0.0758
#
# Epoch 00147: val_loss improved from 0.02539 to 0.02532, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 148/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0260 - mae: 0.0752 - val_loss: 0.0252 - val_mae: 0.0749
#
# Epoch 00148: val_loss improved from 0.02532 to 0.02524, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 149/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0262 - mae: 0.0754 - val_loss: 0.0252 - val_mae: 0.0751
#
# Epoch 00149: val_loss improved from 0.02524 to 0.02522, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 150/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0259 - mae: 0.0752 - val_loss: 0.0253 - val_mae: 0.0753
#
# Epoch 00150: val_loss did not improve from 0.02522
# Epoch 151/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0259 - mae: 0.0749 - val_loss: 0.0252 - val_mae: 0.0755
#
# Epoch 00151: val_loss did not improve from 0.02522
# Epoch 152/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0258 - mae: 0.0749 - val_loss: 0.0252 - val_mae: 0.0746
#
# Epoch 00152: val_loss improved from 0.02522 to 0.02517, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 153/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0260 - mae: 0.0749 - val_loss: 0.0251 - val_mae: 0.0746
#
# Epoch 00153: val_loss improved from 0.02517 to 0.02514, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 154/1000
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0259 - mae: 0.0751 - val_loss: 0.0251 - val_mae: 0.0745
#
# Epoch 00154: val_loss improved from 0.02514 to 0.02505, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 155/1000
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0255 - mae: 0.0745 - val_loss: 0.0250 - val_mae: 0.0750
#
# Epoch 00155: val_loss improved from 0.02505 to 0.02503, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 156/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0261 - mae: 0.0750 - val_loss: 0.0251 - val_mae: 0.0748
#
# Epoch 00156: val_loss did not improve from 0.02503
# Epoch 157/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0258 - mae: 0.0742 - val_loss: 0.0250 - val_mae: 0.0747
#
# Epoch 00157: val_loss improved from 0.02503 to 0.02500, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 158/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0260 - mae: 0.0749 - val_loss: 0.0250 - val_mae: 0.0747
#
# Epoch 00158: val_loss improved from 0.02500 to 0.02496, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 159/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0253 - mae: 0.0741 - val_loss: 0.0249 - val_mae: 0.0745
#
# Epoch 00159: val_loss improved from 0.02496 to 0.02494, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 160/1000
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0255 - mae: 0.0739 - val_loss: 0.0249 - val_mae: 0.0747
#
# Epoch 00160: val_loss improved from 0.02494 to 0.02490, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 161/1000
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0254 - mae: 0.0742 - val_loss: 0.0249 - val_mae: 0.0732
#
# Epoch 00161: val_loss improved from 0.02490 to 0.02486, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 162/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0255 - mae: 0.0739 - val_loss: 0.0249 - val_mae: 0.0736
#
# Epoch 00162: val_loss improved from 0.02486 to 0.02485, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 163/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0254 - mae: 0.0740 - val_loss: 0.0248 - val_mae: 0.0738
#
# Epoch 00163: val_loss improved from 0.02485 to 0.02484, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 164/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0254 - mae: 0.0741 - val_loss: 0.0249 - val_mae: 0.0753
#
# Epoch 00164: val_loss did not improve from 0.02484
# Epoch 165/1000
# ...
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0217 - mae: 0.0653 - val_loss: 0.0217 - val_mae: 0.0652
#
# Epoch 00374: val_loss improved from 0.02176 to 0.02174, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 375/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0218 - mae: 0.0653 - val_loss: 0.0217 - val_mae: 0.0654
#
# Epoch 00375: val_loss improved from 0.02174 to 0.02170, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 376/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0222 - mae: 0.0655 - val_loss: 0.0218 - val_mae: 0.0655
#
# Epoch 00376: val_loss did not improve from 0.02170
# Epoch 377/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0214 - mae: 0.0649 - val_loss: 0.0218 - val_mae: 0.0659
#
# Epoch 00377: val_loss did not improve from 0.02170
# Epoch 378/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0216 - mae: 0.0653 - val_loss: 0.0217 - val_mae: 0.0656
#
# Epoch 00378: val_loss did not improve from 0.02170
# Epoch 379/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0218 - mae: 0.0652 - val_loss: 0.0218 - val_mae: 0.0656
#
# Epoch 00379: val_loss did not improve from 0.02170
# Epoch 380/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0217 - mae: 0.0655 - val_loss: 0.0218 - val_mae: 0.0655
#
# Epoch 00380: val_loss did not improve from 0.02170
# Epoch 381/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0221 - mae: 0.0656 - val_loss: 0.0218 - val_mae: 0.0659
#
# Epoch 00381: val_loss did not improve from 0.02170
# Epoch 382/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0220 - mae: 0.0656 - val_loss: 0.0218 - val_mae: 0.0653
#
# Epoch 00382: val_loss did not improve from 0.02170
# Epoch 383/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0217 - mae: 0.0652 - val_loss: 0.0217 - val_mae: 0.0656
#
# Epoch 00383: val_loss did not improve from 0.02170
# Epoch 384/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0218 - mae: 0.0653 - val_loss: 0.0217 - val_mae: 0.0654
#
# Epoch 00384: val_loss improved from 0.02170 to 0.02169, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 385/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0212 - mae: 0.0646 - val_loss: 0.0218 - val_mae: 0.0656
#
# Epoch 00385: val_loss did not improve from 0.02169
# Epoch 386/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0219 - mae: 0.0652 - val_loss: 0.0217 - val_mae: 0.0662
#
# Epoch 00386: val_loss did not improve from 0.02169
# Epoch 387/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0217 - mae: 0.0651 - val_loss: 0.0217 - val_mae: 0.0656
#
# Epoch 00387: val_loss improved from 0.02169 to 0.02167, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 388/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0214 - mae: 0.0647 - val_loss: 0.0217 - val_mae: 0.0661
#
# Epoch 00388: val_loss did not improve from 0.02167
# Epoch 389/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0212 - mae: 0.0647 - val_loss: 0.0217 - val_mae: 0.0659
#
# Epoch 00389: val_loss did not improve from 0.02167
# Epoch 390/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0217 - mae: 0.0651 - val_loss: 0.0218 - val_mae: 0.0664
#
# Epoch 00390: val_loss did not improve from 0.02167
# Epoch 391/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0220 - mae: 0.0657 - val_loss: 0.0217 - val_mae: 0.0652
#
# Epoch 00391: val_loss did not improve from 0.02167
# Epoch 392/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0218 - mae: 0.0653 - val_loss: 0.0217 - val_mae: 0.0659
#
# Epoch 00392: val_loss did not improve from 0.02167
# Epoch 393/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0217 - mae: 0.0651 - val_loss: 0.0217 - val_mae: 0.0657
#
# Epoch 00393: val_loss did not improve from 0.02167
# Epoch 394/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0218 - mae: 0.0652 - val_loss: 0.0216 - val_mae: 0.0655
#
# Epoch 00394: val_loss improved from 0.02167 to 0.02165, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 395/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0217 - mae: 0.0653 - val_loss: 0.0217 - val_mae: 0.0654
#
# Epoch 00395: val_loss did not improve from 0.02165
#
# Epoch 00395: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 396/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0648 - val_loss: 0.0216 - val_mae: 0.0650
#
# Epoch 00396: val_loss improved from 0.02165 to 0.02159, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 397/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0217 - mae: 0.0648 - val_loss: 0.0216 - val_mae: 0.0650
#
# Epoch 00397: val_loss did not improve from 0.02159
# Epoch 398/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0216 - mae: 0.0648 - val_loss: 0.0216 - val_mae: 0.0650
#
# Epoch 00398: val_loss improved from 0.02159 to 0.02159, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 399/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0648 - val_loss: 0.0216 - val_mae: 0.0656
#
# Epoch 00399: val_loss did not improve from 0.02159
# Epoch 400/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0218 - mae: 0.0649 - val_loss: 0.0216 - val_mae: 0.0647
#
# Epoch 00400: val_loss did not improve from 0.02159
# Epoch 401/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0212 - mae: 0.0643 - val_loss: 0.0216 - val_mae: 0.0651
#
# Epoch 00401: val_loss did not improve from 0.02159
# Epoch 402/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0216 - mae: 0.0650 - val_loss: 0.0216 - val_mae: 0.0645
#
# Epoch 00402: val_loss did not improve from 0.02159
# Epoch 403/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0215 - mae: 0.0645 - val_loss: 0.0216 - val_mae: 0.0648
#
# Epoch 00403: val_loss improved from 0.02159 to 0.02158, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 404/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0216 - mae: 0.0647 - val_loss: 0.0216 - val_mae: 0.0650
#
# Epoch 00404: val_loss improved from 0.02158 to 0.02156, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 405/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0216 - mae: 0.0646 - val_loss: 0.0216 - val_mae: 0.0647
#
# Epoch 00405: val_loss did not improve from 0.02156
# Epoch 406/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0646 - val_loss: 0.0216 - val_mae: 0.0651
#
# Epoch 00406: val_loss improved from 0.02156 to 0.02156, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 407/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0218 - mae: 0.0648 - val_loss: 0.0216 - val_mae: 0.0654
#
# Epoch 00407: val_loss did not improve from 0.02156
# Epoch 408/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0645 - val_loss: 0.0215 - val_mae: 0.0650
#
# Epoch 00408: val_loss improved from 0.02156 to 0.02155, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 409/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0216 - mae: 0.0647 - val_loss: 0.0215 - val_mae: 0.0648
#
# Epoch 00409: val_loss improved from 0.02155 to 0.02154, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 410/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0216 - mae: 0.0649 - val_loss: 0.0216 - val_mae: 0.0649
#
# Epoch 00410: val_loss did not improve from 0.02154
# Epoch 411/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0217 - mae: 0.0648 - val_loss: 0.0215 - val_mae: 0.0649
#
# Epoch 00411: val_loss did not improve from 0.02154
# Epoch 412/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0216 - mae: 0.0646 - val_loss: 0.0216 - val_mae: 0.0650
#
# Epoch 00412: val_loss did not improve from 0.02154
# Epoch 413/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0647
#
# Epoch 00413: val_loss did not improve from 0.02154
# Epoch 414/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0644 - val_loss: 0.0216 - val_mae: 0.0656
#
# Epoch 00414: val_loss did not improve from 0.02154
# Epoch 415/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0215 - mae: 0.0648 - val_loss: 0.0215 - val_mae: 0.0646
#
# Epoch 00415: val_loss did not improve from 0.02154
# Epoch 416/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0645 - val_loss: 0.0215 - val_mae: 0.0647
#
# Epoch 00416: val_loss improved from 0.02154 to 0.02153, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
#
# Epoch 00416: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 417/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0647
#
# Epoch 00417: val_loss improved from 0.02153 to 0.02150, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 418/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0214 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0649
#
# Epoch 00418: val_loss did not improve from 0.02150
# Epoch 419/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0214 - mae: 0.0643 - val_loss: 0.0215 - val_mae: 0.0648
#
# Epoch 00419: val_loss did not improve from 0.02150
# Epoch 420/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0214 - mae: 0.0643 - val_loss: 0.0215 - val_mae: 0.0649
#
# Epoch 00420: val_loss did not improve from 0.02150
# Epoch 421/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0647
#
# Epoch 00421: val_loss did not improve from 0.02150
# Epoch 422/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0212 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0648
#
# Epoch 00422: val_loss did not improve from 0.02150
# Epoch 423/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0650
#
# Epoch 00423: val_loss did not improve from 0.02150
# Epoch 424/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0213 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0649
#
# Epoch 00424: val_loss did not improve from 0.02150
# Epoch 425/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0217 - mae: 0.0645 - val_loss: 0.0215 - val_mae: 0.0650
#
# Epoch 00425: val_loss did not improve from 0.02150
# Epoch 426/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0640 - val_loss: 0.0215 - val_mae: 0.0650
#
# Epoch 00426: val_loss did not improve from 0.02150
# Epoch 427/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0646
#
# Epoch 00427: val_loss did not improve from 0.02150
# Epoch 428/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0213 - mae: 0.0643 - val_loss: 0.0215 - val_mae: 0.0646
#
# Epoch 00428: val_loss improved from 0.02150 to 0.02150, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 429/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0212 - mae: 0.0640 - val_loss: 0.0215 - val_mae: 0.0648
#
# Epoch 00429: val_loss improved from 0.02150 to 0.02150, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 430/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0212 - mae: 0.0642 - val_loss: 0.0215 - val_mae: 0.0650
#
# Epoch 00430: val_loss did not improve from 0.02150
# Epoch 431/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0645
#
# Epoch 00431: val_loss did not improve from 0.02150
# Epoch 432/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0215 - mae: 0.0643 - val_loss: 0.0215 - val_mae: 0.0649
#
# Epoch 00432: val_loss did not improve from 0.02150
# Epoch 433/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0214 - mae: 0.0642 - val_loss: 0.0215 - val_mae: 0.0648
#
# Epoch 00433: val_loss improved from 0.02150 to 0.02148, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 434/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0216 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0648
#
# Epoch 00434: val_loss did not improve from 0.02148
# Epoch 435/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0642 - val_loss: 0.0215 - val_mae: 0.0649
#
# Epoch 00435: val_loss did not improve from 0.02148
# Epoch 436/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0211 - mae: 0.0639 - val_loss: 0.0215 - val_mae: 0.0646
#
# Epoch 00436: val_loss did not improve from 0.02148
# Epoch 437/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0642 - val_loss: 0.0215 - val_mae: 0.0650
#
# Epoch 00437: val_loss did not improve from 0.02148
# Epoch 438/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0214 - mae: 0.0643 - val_loss: 0.0215 - val_mae: 0.0648
#
# Epoch 00438: val_loss did not improve from 0.02148
# Epoch 439/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0212 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0646
#
# Epoch 00439: val_loss did not improve from 0.02148
# Epoch 440/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0212 - mae: 0.0639 - val_loss: 0.0215 - val_mae: 0.0645
#
# Epoch 00440: val_loss improved from 0.02148 to 0.02147, saving model to e:\PTIT\Doan\Detection of Overlapping Bubbles in Industrial Imagery\Models\RDC\rdc_model_mm.h5
# Epoch 441/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0642 - val_loss: 0.0215 - val_mae: 0.0647
#
# Epoch 00441: val_loss did not improve from 0.02147
# Epoch 442/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0216 - mae: 0.0645 - val_loss: 0.0215 - val_mae: 0.0646
#
# Epoch 00442: val_loss did not improve from 0.02147
# Epoch 443/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0214 - mae: 0.0642 - val_loss: 0.0215 - val_mae: 0.0648
#
# Epoch 00443: val_loss did not improve from 0.02147
# Epoch 444/1000
# 97/97 [==============================] - 0s 4ms/step - loss: 0.0213 - mae: 0.0642 - val_loss: 0.0215 - val_mae: 0.0644
#
# Epoch 00444: val_loss did not improve from 0.02147
# Epoch 445/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0644 - val_loss: 0.0215 - val_mae: 0.0645
#
# Epoch 00445: val_loss did not improve from 0.02147
# Epoch 446/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0645 - val_loss: 0.0215 - val_mae: 0.0647
#
# Epoch 00446: val_loss did not improve from 0.02147
# Epoch 447/1000
# 97/97 [==============================] - 0s 3ms/step - loss: 0.0213 - mae: 0.0642 - val_loss: 0.0215 - val_mae: 0.0647
#
# Epoch 00447: val_loss did not improve from 0.02147

# %%
# 4. Visualize History
plot_training_history(history)

# %%
# 5. Visualize Predictions
evaluate_predictions(model, X, Y)
# Out:
# Evaluating sample predictions...

# %%
# 6. Calculate Accuracy
calculate_area_accuracy(model, X, Y)
# Out:
# Calculating Mean Area Accuracy...
# Mean Area Accuracy: 0.9636 (96.36%)
# 0.9635580846461864
